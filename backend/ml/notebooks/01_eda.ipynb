# %% [markdown]
# # 01 - Exploratory Data Analysis (EDA)

# %%
# Cell 1 — Import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 7
#       5 get_ipython().run_line_magic('pip', 'install matplotlib -q')
#       6 import matplotlib.pyplot as plt
# ----> 7 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Cell 2 — Load dữ liệu
df = pd.read_csv('../data/diabetes.csv')
print(df.shape)       # (768, 9)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Cell 3 — Thông tin tổng quan
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
# Cell 4 — Kiểm tra giá trị 0 bất thường
# Glucose, BloodPressure, BMI, SkinThickness, Insulin không thể = 0
zero_cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for col in zero_cols:
    count = (df[col] == 0).sum()
    print(f'{col}: {count} giá trị bằng 0 ({count/len(df)*100:.1f}%)')
# Out:
# Glucose: 5 giá trị bằng 0 (0.7%)
# BloodPressure: 35 giá trị bằng 0 (4.6%)
# SkinThickness: 227 giá trị bằng 0 (29.6%)
# Insulin: 374 giá trị bằng 0 (48.7%)
# BMI: 11 giá trị bằng 0 (1.4%)

# %%
# Cell 5 — Phân phối nhãn (class imbalance)
print(df['Outcome'].value_counts())
df['Outcome'].value_counts().plot(kind='bar', color=['steelblue','tomato'])
plt.title('Phân phối nhãn: 0=Không bệnh, 1=Có bệnh')
plt.xticks(rotation=0)
plt.show()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 # Cell 5 — Phân phối nhãn (class imbalance)
#       2 print(df['Outcome'].value_counts())
# ----> 3 df['Outcome'].value_counts().plot(kind='bar', color=['steelblue','tomato'])
#       4 plt.title('Phân phối nhãn: 0=Không bệnh, 1=Có bệnh')
#       5 plt.xticks(rotation=0)
#
# File d:\Workspace\Python\Diabetes-Diagnosis-app\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File d:\Workspace\Python\Diabetes-Diagnosis-app\.venv\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
#    2255 return module
#
# File d:\Workspace\Python\Diabetes-Diagnosis-app\.venv\Lib\site-packages\pandas\plotting\_core.py:2183, in _load_backend(backend)
#    2181         module = importlib.import_module("pandas.plotting._matplotlib")
#    2182     except ImportError:
# -> 2183         raise ImportError(
#    2184             "matplotlib is required for plotting when the "
#    2185             'default backend "matplotlib" is selected.'
#    2186         ) from None
#    2187     return module
#    2189 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.

# %%
# Cell 6 — Heatmap tương quan
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Ma trận tương quan giữa các đặc trưng')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Cell 6 — Heatmap tương quan
# ----> 2 plt.figure(figsize=(10, 8))
#       3 sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
#       4 plt.title('Ma trận tương quan giữa các đặc trưng')
#
# NameError: name 'plt' is not defined

# %%
# Cell 7 — Phân phối từng đặc trưng
df.hist(figsize=(12, 10), bins=20, color='steelblue', edgecolor='white')
plt.suptitle('Phân phối các chỉ số sinh học')
plt.tight_layout()
plt.show()
